# %% [markdown]
# <a href="https://colab.research.google.com/github/odingherdiana/Business-Intelligence/blob/main/proyek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly as py
import plotly.graph_objs as go

from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Data Exploration

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/02_My Courses Files/KOM1623-Teori Data Mining Terapan/proyek/dataset/Rawdata_vFinal.csv')

df.head()
# Out:
#    KodeKecamatan  pct_Aset  pct_Omset  pct_BidangUsaha
# 0              1     63.83       8.69            42.43
# 1              1     63.83       8.69            42.43
# 2              1     63.83       8.69            42.43
# 3              1     63.83      90.82            42.43
# 4              1     63.83      90.82            42.43

# %%
df.columns
# Out:
# Index(['KodeKecamatan', 'pct_Aset', 'pct_Omset', 'pct_BidangUsaha'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1645 entries, 0 to 1644
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   KodeKecamatan    1645 non-null   int64
#  1   pct_Aset         1645 non-null   float64
#  2   pct_Omset        1645 non-null   float64
#  3   pct_BidangUsaha  1645 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 51.5 KB

# %%
df.describe()
# Out:
#        KodeKecamatan     pct_Aset    pct_Omset  pct_BidangUsaha
# count    1645.000000  1645.000000  1645.000000      1645.000000
# mean       24.447416    50.942675    83.241137        24.857538
# std        12.907181    17.956591    23.852903        15.601267
# min         1.000000     4.560000     0.490000         0.060000
# 25%        14.000000    31.610000    90.820000        14.220000
# 50%        26.000000    63.830000    90.820000        15.500000
# 75%        35.000000    63.830000    90.820000        42.430000
# max        47.000000    63.830000    90.820000        42.430000

# %% [markdown]
# Checking for null values

# %%
df.isnull().sum()
# Out:
# KodeKecamatan      0
# pct_Aset           0
# pct_Omset          0
# pct_BidangUsaha    0
# dtype: int64

# %%
plt.figure(1 , figsize = (15 , 6))
n = 0
for x in ['pct_BidangUsaha' , 'pct_Aset' , 'pct_Omset']:
    n += 1
    plt.subplot(1 , 3 , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    sns.distplot(df[x] , bins = 15)
    plt.title('Distplot of {}'.format(x))
plt.show()

# %%
sns.pairplot(df, vars = ['pct_Aset', 'pct_Omset', 'pct_BidangUsaha'], hue = "KodeKecamatan")

# %%
X1 = df[['pct_BidangUsaha' , 'pct_Aset']].iloc[: , :].values
inertia = []
for n in range(1 , 15):
    algorithm = (KMeans(n_clusters = n ,init='k-means++', n_init = 10 ,max_iter=300,
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
    algorithm.fit(X1)
    inertia.append(algorithm.inertia_)

# %%
plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 15) , inertia , 'o')
plt.plot(np.arange(1 , 15) , inertia , '-' , alpha = 0.5)
plt.xlabel('Number of Clusters') , plt.ylabel('Inertia')
plt.show()

# %%
Applying KMeans for k=4

# %% [markdown]
# Normalisasi, binning dan splitting dataset

# %%
normalize_data(d, d.columns)
d.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-c57d63f01ed4> in <cell line: 1>()
# ----> 1 normalize_data(d, d.columns)
#       2 d.head()
#
# NameError: name 'd' is not defined

# %% [markdown]
# Modelling

# %%
#selecting features
X = d[['Kode Kecamatan', 'Bidang Usaha','Aset', 'Omset']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-509b99056481> in <cell line: 2>()
#       1 #selecting features
# ----> 2 X = d[['Kode Kecamatan', 'Bidang Usaha','Aset', 'Omset']]
#
# NameError: name 'd' is not defined
